# %%
import requests
import pandas as pd
import sqlite3
from datetime import datetime

def fetch_weather():
    url = "https://api.open-meteo.com/v1/forecast"
    params = {
        "latitude": 29.87,
        "longitude": 77.89,
        "current_weather": True
    }
    response = requests.get(url, params=params)
    data = response.json()
    current = data['current_weather']

    row = {
        "timestamp": datetime.now().strftime("%Y-%m-%d %H:%M:%S"),
        "temperature": current['temperature'],
        "windspeed": current['windspeed'],
        "weathercode": current['weathercode'],
        "city": "Roorkee"
    }
    return pd.DataFrame([row])

def save_to_db(df, table_name):
    conn = sqlite3.connect("data/city_pulse.db")
    df.to_sql(table_name, conn, if_exists="append", index=False)
    conn.close()

df_weather = fetch_weather()
save_to_db(df_weather, "weather_logs")
print("✅ Weather saved!")
df_weather
# Out:
# ✅ Weather saved!
#              timestamp  temperature  windspeed  weathercode     city
# 0  2026-06-19 14:18:54         35.7       10.5           95  Roorkee

# %%
def fetch_air_quality():
    url = "https://air-quality-api.open-meteo.com/v1/air-quality"
    params = {
        "latitude": 29.87,
        "longitude": 77.89,
        "hourly": "pm10,pm2_5,carbon_monoxide,nitrogen_dioxide"
    }
    response = requests.get(url, params=params)
    data = response.json()

    row = {
        "timestamp": datetime.now().strftime("%Y-%m-%d %H:%M:%S"),
        "pm2_5": data['hourly']['pm2_5'][0],
        "pm10": data['hourly']['pm10'][0],
        "carbon_monoxide": data['hourly']['carbon_monoxide'][0],
        "nitrogen_dioxide": data['hourly']['nitrogen_dioxide'][0],
        "city": "Roorkee"
    }
    return pd.DataFrame([row])

df_air = fetch_air_quality()
save_to_db(df_air, "air_quality_logs")
print("✅ Air quality saved!")
df_air
# Out:
# ✅ Air quality saved!
#              timestamp  pm2_5  pm10  carbon_monoxide  nitrogen_dioxide  \
# 0  2026-06-19 14:19:35   70.1  97.6            745.0              42.4
#
#       city
# 0  Roorkee

# %%
from textblob import TextBlob

# Real world: Swiggy reads reviews → auto tags positive/negative
# We: Read citizen complaints → find positive/negative

complaints = [
    "Water supply has been cut for 3 days in sector 5",
    "Roads are excellent after repair, very smooth now",
    "Garbage not collected since Monday, very bad smell",
    "Street lights working perfectly, feel safe at night",
    "Electricity goes off every evening for 2 hours",
    "New park is beautiful, children love playing there",
    "Drainage system is blocked, water flooding the road",
    "Bus service is very punctual and clean"
]

rows = []
for text in complaints:
    blob = TextBlob(text)
    score = blob.sentiment.polarity

    if score > 0.1:
        label = "Positive"
    elif score < -0.1:
        label = "Negative"
    else:
        label = "Neutral"

    rows.append({
        "complaint": text,
        "sentiment_score": round(score, 2),
        "sentiment_label": label
    })

df_complaints = pd.DataFrame(rows)
save_to_db(df_complaints, "complaints_analysis")
print("✅ Complaints analyzed!")
df_complaints
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 from textblob import TextBlob
#       3 # Real world: Swiggy reads reviews → auto tags positive/negative
#       4 # We: Read citizen complaints → find positive/negative
#       6 complaints = [
#       7     "Water supply has been cut for 3 days in sector 5",
#       8     "Roads are excellent after repair, very smooth now",
#    (...)     14     "Bus service is very punctual and clean"
#      15 ]
#
# ModuleNotFoundError: No module named 'textblob'

# %%
# !pip install textblob
# !python -m textblob.download_corpora
# Out:
# Collecting textblob
#   Downloading textblob-0.20.0-py3-none-any.whl.metadata (4.0 kB)
# Requirement already satisfied: nltk>=3.9 in c:\users\disha sharma\anaconda3\lib\site-packages (from textblob) (3.9.2)
# Requirement already satisfied: click in c:\users\disha sharma\anaconda3\lib\site-packages (from nltk>=3.9->textblob) (8.2.1)
# Requirement already satisfied: joblib in c:\users\disha sharma\anaconda3\lib\site-packages (from nltk>=3.9->textblob) (1.5.2)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\disha sharma\anaconda3\lib\site-packages (from nltk>=3.9->textblob) (2025.9.1)
# Requirement already satisfied: tqdm in c:\users\disha sharma\anaconda3\lib\site-packages (from nltk>=3.9->textblob) (4.67.1)
# Requirement already satisfied: colorama in c:\users\disha sharma\anaconda3\lib\site-packages (from click->nltk>=3.9->textblob) (0.4.6)
# Downloading textblob-0.20.0-py3-none-any.whl (624 kB)
#    ---------------------------------------- 0.0/625.0 kB ? eta -:--:--
#    ---------------------------------------- 0.0/625.0 kB ? eta -:--:--
#    ---------------- ----------------------- 262.1/625.0 kB ? eta -:--:--
#    ---------------------------------------- 625.0/625.0 kB 1.2 MB/s  0:00:00
# Installing collected packages: textblob
# Successfully installed textblob-0.20.0
# Finished.
# [nltk_data] Downloading package brown to C:\Users\DISHA
# [nltk_data]     SHARMA\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\brown.zip.
# [nltk_data] Downloading package punkt_tab to C:\Users\DISHA
# [nltk_data]     SHARMA\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt_tab.zip.
# [nltk_data] Downloading package wordnet to C:\Users\DISHA
# [nltk_data]     SHARMA\AppData\Roaming\nltk_data...
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     C:\Users\DISHA SHARMA\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping taggers\averaged_perceptron_tagger_eng.zip.
# [nltk_data] Downloading package conll2000 to C:\Users\DISHA
# [nltk_data]     SHARMA\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\conll2000.zip.
# [nltk_data] Downloading package movie_reviews to C:\Users\DISHA
# [nltk_data]     SHARMA\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\movie_reviews.zip.

# %%
from textblob import TextBlob

# Real world: Swiggy reads reviews → auto tags positive/negative
# We: Read citizen complaints → find positive/negative

complaints = [
    "Water supply has been cut for 3 days in sector 5",
    "Roads are excellent after repair, very smooth now",
    "Garbage not collected since Monday, very bad smell",
    "Street lights working perfectly, feel safe at night",
    "Electricity goes off every evening for 2 hours",
    "New park is beautiful, children love playing there",
    "Drainage system is blocked, water flooding the road",
    "Bus service is very punctual and clean"
]

rows = []
for text in complaints:
    blob = TextBlob(text)
    score = blob.sentiment.polarity

    if score > 0.1:
        label = "Positive"
    elif score < -0.1:
        label = "Negative"
    else:
        label = "Neutral"

    rows.append({
        "complaint": text,
        "sentiment_score": round(score, 2),
        "sentiment_label": label
    })

df_complaints = pd.DataFrame(rows)
save_to_db(df_complaints, "complaints_analysis")
print("✅ Complaints analyzed!")
df_complaints
# Out:
# ✅ Complaints analyzed!
#                                            complaint  sentiment_score  \
# 0   Water supply has been cut for 3 days in sector 5             0.00
# 1  Roads are excellent after repair, very smooth now             0.76
# 2  Garbage not collected since Monday, very bad s...            -0.91
# 3  Street lights working perfectly, feel safe at ...             0.75
# 4     Electricity goes off every evening for 2 hours             0.00
# 5  New park is beautiful, children love playing t...             0.50
# 6  Drainage system is blocked, water flooding the...             0.00
# 7             Bus service is very punctual and clean             0.28
#
#   sentiment_label
# 0         Neutral
# 1        Positive
# 2        Negative
# 3        Positive
# 4         Neutral
# 5        Positive
# 6         Neutral
# 7        Positive

# %%
# !pip install textblob scikit-learn statsmodels plotly pandas requests openpyxl streamlit
# Out:
# Requirement already satisfied: textblob in c:\users\disha sharma\anaconda3\lib\site-packages (0.20.0)
# Requirement already satisfied: scikit-learn in c:\users\disha sharma\anaconda3\lib\site-packages (1.7.2)
# Requirement already satisfied: statsmodels in c:\users\disha sharma\anaconda3\lib\site-packages (0.14.5)
# Requirement already satisfied: plotly in c:\users\disha sharma\anaconda3\lib\site-packages (6.6.0)
# Requirement already satisfied: pandas in c:\users\disha sharma\anaconda3\lib\site-packages (2.3.3)
# Requirement already satisfied: requests in c:\users\disha sharma\anaconda3\lib\site-packages (2.32.5)
# Requirement already satisfied: openpyxl in c:\users\disha sharma\anaconda3\lib\site-packages (3.1.5)
# Requirement already satisfied: streamlit in c:\users\disha sharma\anaconda3\lib\site-packages (1.51.0)
# Requirement already satisfied: nltk>=3.9 in c:\users\disha sharma\anaconda3\lib\site-packages (from textblob) (3.9.2)
# Requirement already satisfied: numpy>=1.22.0 in c:\users\disha sharma\anaconda3\lib\site-packages (from scikit-learn) (2.3.5)
# Requirement already satisfied: scipy>=1.8.0 in c:\users\disha sharma\anaconda3\lib\site-packages (from scikit-learn) (1.16.3)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\disha sharma\anaconda3\lib\site-packages (from scikit-learn) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\disha sharma\anaconda3\lib\site-packages (from scikit-learn) (3.5.0)
# Requirement already satisfied: patsy>=0.5.6 in c:\users\disha sharma\anaconda3\lib\site-packages (from statsmodels) (1.0.1)
# Requirement already satisfied: packaging>=21.3 in c:\users\disha sharma\anaconda3\lib\site-packages (from statsmodels) (25.0)
# Requirement already satisfied: narwhals>=1.15.1 in c:\users\disha sharma\anaconda3\lib\site-packages (from plotly) (2.7.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\disha sharma\anaconda3\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\disha sharma\anaconda3\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\disha sharma\anaconda3\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\disha sharma\anaconda3\lib\site-packages (from requests) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\disha sharma\anaconda3\lib\site-packages (from requests) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\disha sharma\anaconda3\lib\site-packages (from requests) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\disha sharma\anaconda3\lib\site-packages (from requests) (2026.1.4)
# Requirement already satisfied: et-xmlfile in c:\users\disha sharma\anaconda3\lib\site-packages (from openpyxl) (2.0.0)
# Requirement already satisfied: altair!=5.4.0,!=5.4.1,<6,>=4.0 in c:\users\disha sharma\anaconda3\lib\site-packages (from streamlit) (5.5.0)
# Requirement already satisfied: blinker<2,>=1.5.0 in c:\users\disha sharma\anaconda3\lib\site-packages (from streamlit) (1.9.0)
# Requirement already satisfied: cachetools<7,>=4.0 in c:\users\disha sharma\anaconda3\lib\site-packages (from streamlit) (5.5.1)
# Requirement already satisfied: click<9,>=7.0 in c:\users\disha sharma\anaconda3\lib\site-packages (from streamlit) (8.2.1)
# Requirement already satisfied: pillow<13,>=7.1.0 in c:\users\disha sharma\anaconda3\lib\site-packages (from streamlit) (12.0.0)
# Requirement already satisfied: protobuf<7,>=3.20 in c:\users\disha sharma\anaconda3\lib\site-packages (from streamlit) (5.29.3)
# Requirement already satisfied: pyarrow<22,>=7.0 in c:\users\disha sharma\anaconda3\lib\site-packages (from streamlit) (21.0.0)
# Requirement already satisfied: tenacity<10,>=8.1.0 in c:\users\disha sharma\anaconda3\lib\site-packages (from streamlit) (9.1.2)
# Requirement already satisfied: toml<2,>=0.10.1 in c:\users\disha sharma\anaconda3\lib\site-packages (from streamlit) (0.10.2)
# Requirement already satisfied: typing-extensions<5,>=4.4.0 in c:\users\disha sharma\anaconda3\lib\site-packages (from streamlit) (4.15.0)
# Requirement already satisfied: watchdog<7,>=2.1.5 in c:\users\disha sharma\anaconda3\lib\site-packages (from streamlit) (6.0.0)
# Requirement already satisfied: gitpython!=3.1.19,<4,>=3.0.7 in c:\users\disha sharma\anaconda3\lib\site-packages (from streamlit) (3.1.45)
# Requirement already satisfied: tornado!=6.5.0,<7,>=6.0.3 in c:\users\disha sharma\anaconda3\lib\site-packages (from streamlit) (6.5.1)
# Requirement already satisfied: jinja2 in c:\users\disha sharma\anaconda3\lib\site-packages (from altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit) (3.1.6)
# Requirement already satisfied: jsonschema>=3.0 in c:\users\disha sharma\anaconda3\lib\site-packages (from altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit) (4.25.0)
# Requirement already satisfied: colorama in c:\users\disha sharma\anaconda3\lib\site-packages (from click<9,>=7.0->streamlit) (0.4.6)
# Requirement already satisfied: gitdb<5,>=4.0.1 in c:\users\disha sharma\anaconda3\lib\site-packages (from gitpython!=3.1.19,<4,>=3.0.7->streamlit) (4.0.12)
# Requirement already satisfied: smmap<6,>=3.0.1 in c:\users\disha sharma\anaconda3\lib\site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit) (4.0.0)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\disha sharma\anaconda3\lib\site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit) (25.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\disha sharma\anaconda3\lib\site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\disha sharma\anaconda3\lib\site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit) (0.37.0)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\disha sharma\anaconda3\lib\site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit) (0.28.0)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\disha sharma\anaconda3\lib\site-packages (from nltk>=3.9->textblob) (2025.9.1)
# Requirement already satisfied: tqdm in c:\users\disha sharma\anaconda3\lib\site-packages (from nltk>=3.9->textblob) (4.67.1)
# Requirement already satisfied: six>=1.5 in c:\users\disha sharma\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\disha sharma\anaconda3\lib\site-packages (from jinja2->altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit) (3.0.2)

# %%
from sklearn.ensemble import IsolationForest
import random

random.seed(42)

# Simulate 30 days normal weather
rows = []
for i in range(30):
    rows.append({
        "timestamp": f"2024-06-{i+1:02d}",
        "temperature": round(random.uniform(28, 38), 1),
        "windspeed": round(random.uniform(5, 20), 1)
    })

# Add 2 anomalies
rows.append({"timestamp": "2024-07-01", "temperature": 65.0, "windspeed": 5.0})
rows.append({"timestamp": "2024-07-02", "temperature": 10.0, "windspeed": 95.0})

df_anomaly = pd.DataFrame(rows)

model = IsolationForest(contamination=0.1, random_state=42)
df_anomaly['anomaly_flag'] = model.fit_predict(df_anomaly[['temperature','windspeed']])
df_anomaly['status'] = df_anomaly['anomaly_flag'].apply(
    lambda x: 'Unusual' if x == -1 else 'Normal'
)

save_to_db(df_anomaly, "weather_anomalies")
print("✅ Anomaly detection done!")
df_anomaly[['timestamp','temperature','windspeed','status']]
# Out:
# ✅ Anomaly detection done!
#      timestamp  temperature  windspeed   status
# 0   2024-06-01         34.4        5.4   Normal
# 1   2024-06-02         30.8        8.3   Normal
# 2   2024-06-03         35.4       15.2   Normal
# 3   2024-06-04         36.9        6.3   Normal
# 4   2024-06-05         32.2        5.4   Normal
# 5   2024-06-06         30.2       12.6   Normal
# 6   2024-06-07         28.3        8.0   Normal
# 7   2024-06-08         34.5       13.2   Normal
# 8   2024-06-09         30.2       13.8   Normal
# 9   2024-06-10         36.1        5.1   Normal
# 10  2024-06-11         36.1       15.5   Normal
# 11  2024-06-12         31.4        7.3   Normal
# 12  2024-06-13         37.6       10.0   Normal
# 13  2024-06-14         28.9        6.5   Normal
# 14  2024-06-15         36.5       14.1   Normal
# 15  2024-06-16         36.1       15.9   Normal
# 16  2024-06-17         33.4       19.6  Unusual
# 17  2024-06-18         31.8       13.3   Normal
# 18  2024-06-19         36.3       14.3   Normal
# 19  2024-06-20         36.6       13.7   Normal
# 20  2024-06-21         35.0        5.7   Normal
# 21  2024-06-22         30.3        9.3   Normal
# 22  2024-06-23         28.8        8.5   Normal
# 23  2024-06-24         29.0        9.2   Normal
# 24  2024-06-25         34.4       10.5   Normal
# 25  2024-06-26         31.7        8.1   Normal
# 26  2024-06-27         30.7       19.0  Unusual
# 27  2024-06-28         34.5       14.1   Normal
# 28  2024-06-29         29.7       15.9   Normal
# 29  2024-06-30         29.6       10.7   Normal
# 30  2024-07-01         65.0        5.0  Unusual
# 31  2024-07-02         10.0       95.0  Unusual

# %%
from statsmodels.tsa.holtwinters import ExponentialSmoothing

# Real world: Weather app predicts next 7 days
# We: Predict next 7 days temperature for Roorkee

temp_series = df_anomaly['temperature'].iloc[:30].reset_index(drop=True)
model = ExponentialSmoothing(temp_series, trend='add').fit()
forecast = model.forecast(7)

df_forecast = pd.DataFrame({
    "day": [f"Day +{i}" for i in range(1, 8)],
    "forecasted_temp": forecast.round(1).values
})

save_to_db(df_forecast, "forecast")
print("✅ Forecast done!")
df_forecast
# Out:
# ✅ Forecast done!
#       day  forecasted_temp
# 0  Day +1             31.8
# 1  Day +2             31.7
# 2  Day +3             31.6
# 3  Day +4             31.6
# 4  Day +5             31.5
# 5  Day +6             31.4
# 6  Day +7             31.4

# %%
import plotly.express as px

# Chart 1 - Anomalies
fig1 = px.scatter(
    df_anomaly, x='timestamp', y='temperature',
    color='status', size='windspeed',
    title='🌡️ Temperature — Anomalies Highlighted',
    color_discrete_map={'Normal':'#2196F3','Unusual':'#F44336'}
)
fig1.write_html("output/charts/anomalies.html")
fig1.show()

# Chart 2 - Sentiment
fig2 = px.pie(
    df_complaints, names='sentiment_label',
    title='📝 Complaint Sentiments',
    color_discrete_sequence=['#4CAF50','#F44336','#9E9E9E']
)
fig2.write_html("output/charts/sentiment.html")
fig2.show()

# Chart 3 - Air Quality
fig3 = px.bar(
    df_air, x='city', y=['pm2_5','pm10'],
    title='💨 Air Quality — Roorkee',
    barmode='group'
)
fig3.write_html("output/charts/air_quality.html")
fig3.show()

# Chart 4 - Forecast
fig4 = px.line(
    df_forecast, x='day', y='forecasted_temp',
    title='📈 7-Day Temperature Forecast',
    markers=True
)
fig4.write_html("output/charts/forecast.html")
fig4.show()

print("✅ All charts saved in output/charts/")
# Out:
# ✅ All charts saved in output/charts/

# %%
import os

os.chdir("C:/Users/DISHA SHARMA/projects/city-smart-pulse")
print("✅ Working directory:", os.getcwd())
# Out:
# ✅ Working directory: C:\Users\DISHA SHARMA\projects\city-smart-pulse

# %%
os.makedirs("data", exist_ok=True)
os.makedirs("output/charts", exist_ok=True)
print("✅ Folders ready")
# Out:
# ✅ Folders ready

# %%
import sqlite3
import pandas as pd

# Test if DB is working
conn = sqlite3.connect("data/city_pulse.db")
tables = pd.read_sql("SELECT name FROM sqlite_master WHERE type='table'", conn)
conn.close()

print("✅ Database found!")
print("Tables inside:", tables)
# Out:
# ✅ Database found!
# Tables inside:                   name
# 0         weather_logs
# 1     air_quality_logs
# 2  complaints_analysis
# 3    weather_anomalies
# 4             forecast

# %%
conn = sqlite3.connect("data/city_pulse.db")

try:
    with pd.ExcelWriter("data/city_pulse_data.xlsx", engine='openpyxl') as writer:
        
        for table, sheet in [
            ("weather_logs", "Weather"),
            ("air_quality_logs", "AirQuality"),
            ("complaints_analysis", "Complaints"),
            ("weather_anomalies", "Anomalies"),
            ("forecast", "Forecast")
        ]:
            try:
                df = pd.read_sql(f"SELECT * FROM {table}", conn)
                df.to_excel(writer, sheet_name=sheet, index=False)
                print(f"✅ {sheet} sheet saved — {len(df)} rows")
            except Exception as e:
                print(f"⚠️ Skipped {sheet}: {e}")

    print("\n✅ Excel file saved at: data/city_pulse_data.xlsx")

except Exception as e:
    print("❌ Error:", e)

conn.close()
# Out:
# ✅ Weather sheet saved — 1 rows
# ✅ AirQuality sheet saved — 1 rows
# ✅ Complaints sheet saved — 8 rows
# ✅ Anomalies sheet saved — 32 rows
# ✅ Forecast sheet saved — 7 rows
#
# ✅ Excel file saved at: data/city_pulse_data.xlsx
